# %% [markdown]
# # Analysis Report IV

# %% [markdown]
# ## Loading dataset

# %%
# libs
import pandas as pd

# %%
df_residential = pd.read_csv('datasets/residential.csv', sep=';')
print(df_residential.shape)
df_residential.head()
# Out:
# (23060, 9)
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 2       390.0  20.0
# 3       230.0   NaN
# 4         NaN   NaN

# %% [markdown]
# ## Exploring Data

# %%
# counting 'Apartamento' values
apartment_filter = df_residential.Tipo == 'Apartamento'
df_apartments = df_residential.loc[apartment_filter].reset_index(drop=True)

df_apartments
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0      Apartamento                Centro        1      0       0    15
# 1      Apartamento          Higienópolis        1      0       0    48
# 2      Apartamento          Vista Alegre        3      1       0    70
# 3      Apartamento              Cachambi        2      0       0    50
# 4      Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 19527  Apartamento        Vila Valqueire        2      0       0    52
# 19528  Apartamento                 Méier        2      0       0    70
# 19529  Apartamento           Jacarepaguá        3      1       2    78
# 19530  Apartamento  São Francisco Xavier        2      1       0    48
# 19531  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0       800.0       390.0  20.0
# 1       800.0       230.0   NaN
# 2      1200.0         NaN   NaN
# 3      1300.0       301.0  17.0
# 4      1200.0         NaN   NaN
# ...       ...         ...   ...
# 19527  1000.0       550.0   NaN
# 19528   900.0       490.0  48.0
# 19529  1800.0       800.0  40.0
# 19530  1400.0       509.0  37.0
# 19531  3000.0       760.0   NaN
#
# [19532 rows x 9 columns]

# %%
# counting 'Casa%' values
ls_house_type = [
    'Casa',
    'Casa de Condomínio',
    'Casa de Vila'
]
house_filter = df_residential.Tipo.isin(ls_house_type)
df_houses = df_residential.loc[house_filter].reset_index(drop=True)

df_houses
# Out:
#                     Tipo                   Bairro  Quartos  Vagas  Suites  \
# 0                   Casa          Jardim Botânico        2      0       1
# 1     Casa de Condomínio          Barra da Tijuca        5      4       5
# 2     Casa de Condomínio                    Ramos        2      2       0
# 3     Casa de Condomínio                  Taquara        3      1       1
# 4     Casa de Condomínio          Barra da Tijuca        4      3       2
# ...                  ...                      ...      ...    ...     ...
# 2207  Casa de Condomínio  Freguesia (Jacarepaguá)        3      3       1
# 2208                Casa            Bento Ribeiro        2      1       0
# 2209  Casa de Condomínio          Barra da Tijuca        3      5       3
# 2210                Casa                   Centro        5      0       1
# 2211  Casa de Condomínio          Barra da Tijuca        5      3       4
#
#       Area    Valor  Condominio    IPTU
# 0      100   7000.0         NaN     NaN
# 1      750  22000.0         NaN     NaN
# 2       65   1000.0         NaN     NaN
# 3      115   2000.0         NaN     NaN
# 4      466   7500.0      2695.0     NaN
# ...    ...      ...         ...     ...
# 2207   155   2000.0       530.0  1250.0
# 2208    60   1400.0         NaN     NaN
# 2209  1000  20000.0      3000.0     NaN
# 2210   160   5000.0         NaN    80.0
# 2211   450  15000.0      1711.0  2332.0
#
# [2212 rows x 9 columns]

# %%
# counting values where 'Area' is between 60 and 100
area_filter = df_residential.Area.between(60, 100)
df_area_60_100 = df_residential.loc[area_filter].reset_index(drop=True)

df_area_60_100
# Out:
#                     Tipo                    Bairro  Quartos  Vagas  Suites  \
# 0                   Casa           Jardim Botânico        2      0       1
# 1            Apartamento              Vista Alegre        3      1       0
# 2     Casa de Condomínio                     Ramos        2      2       0
# 3            Apartamento                    Grajaú        2      1       0
# 4            Apartamento       Lins de Vasconcelos        3      1       1
# ...                  ...                       ...      ...    ...     ...
# 8970         Apartamento  Recreio dos Bandeirantes        3      2       1
# 8971         Apartamento                    Leblon        3      0       1
# 8972         Apartamento                     Méier        2      0       0
# 8973         Apartamento               Jacarepaguá        3      1       2
# 8974         Apartamento                    Leblon        2      0       0
#
#       Area   Valor  Condominio   IPTU
# 0      100  7000.0         NaN    NaN
# 1       70  1200.0         NaN    NaN
# 2       65  1000.0         NaN    NaN
# 3       70  1500.0       642.0   74.0
# 4       90  1500.0       455.0   14.0
# ...    ...     ...         ...    ...
# 8970    88  1550.0       790.0    NaN
# 8971    80  3000.0      1010.0  249.0
# 8972    70   900.0       490.0   48.0
# 8973    78  1800.0       800.0   40.0
# 8974    70  3000.0       760.0    NaN
#
# [8975 rows x 9 columns]

# %%
# counting values where 'Quartos' is at least 4 and 'Valor' is up to 2000
room_and_price_filter = (df_residential.Quartos >= 4) & (df_residential.Valor < 2000)
df_room_and_price = df_residential.loc[room_and_price_filter].reset_index(drop=True)

df_room_and_price
# Out:
#                   Tipo                    Bairro  Quartos  Vagas  Suites  \
# 0          Apartamento  Recreio dos Bandeirantes        4      2       2
# 1          Apartamento                   Taquara        4      1       1
# 2                 Casa              Campo Grande        4      1       4
# 3                 Casa         Engenho de Dentro        4      3       0
# 4          Apartamento  Recreio dos Bandeirantes        4      2       2
# 5         Casa de Vila                     Méier        4      0       1
# 6                 Casa              Campo Grande        4      1       0
# 7          Apartamento              Campo Grande        4      2       1
# 8          Apartamento  Recreio dos Bandeirantes        4      2       1
# 9          Apartamento               Cidade Nova        4      0       0
# 10         Apartamento                 Pechincha        4      1       2
# 11                Casa                 Riachuelo        4      0       1
# 12                Casa                     Méier        4      1       1
# 13         Apartamento  Recreio dos Bandeirantes        4      2       3
# 14         Apartamento  Recreio dos Bandeirantes        4      3       2
# 15         Apartamento  Recreio dos Bandeirantes        4      2       1
# 16         Apartamento  Recreio dos Bandeirantes        4      2       1
# 17  Casa de Condomínio                   Taquara        4      1       0
# 18                Casa              Santo Cristo        5      0       0
# 19         Apartamento                      Leme        4      0       1
# 20         Apartamento  Recreio dos Bandeirantes        4      2       1
# 21         Apartamento                   Camorim        4      1       1
# 22         Apartamento           Barra da Tijuca        4      3       4
# 23                Casa                Praça Seca        4      1       1
# 24  Casa de Condomínio   Freguesia (Jacarepaguá)        4      2       1
# 25                Casa        Pedra de Guaratiba        4      1       0
# 26         Apartamento              Campo Grande        4      2       2
# 27         Apartamento  Recreio dos Bandeirantes        4      2       2
# 28         Apartamento              Rio Comprido        4      1       0
# 29                Casa              Campo Grande        4      3       0
# 30         Apartamento                   Taquara        4      3       1
# 31                Casa              Campo Grande        4      0       1
# 32                Casa              Campo Grande        4      0       0
# 33                Casa              Braz de Pina        4      1       0
# 34                Casa              Campo Grande        4      1       3
# 35                Casa              Campo Grande        4      1       2
# 36         Apartamento              Campo Grande        4      1       1
# 37         Apartamento           Barra da Tijuca        4      3       4
# 38         Apartamento             Vargem Grande        4      0       1
# 39         Apartamento  Recreio dos Bandeirantes        4      2       2
# 40                Casa              Campo Grande        4      2       0
#
#     Area   Valor  Condominio   IPTU
# 0    160  1900.0       830.0    NaN
# 1    110  1900.0         NaN    NaN
# 2    100  1600.0         NaN    NaN
# 3    120  1500.0         NaN    NaN
# 4    125  1700.0         NaN   90.0
# 5     85  1600.0         NaN    NaN
# 6    140  1700.0         NaN    NaN
# 7    115  1900.0       500.0    NaN
# 8    105  1900.0      1492.0  205.0
# 9    110  1300.0         NaN    NaN
# 10   178  1900.0      1100.0  270.0
# 11   100  1800.0         NaN   40.0
# 12   125  1900.0         NaN    NaN
# 13   280  1800.0      1400.0  580.0
# 14   250  1500.0      1380.0  700.0
# 15   160  1900.0      1093.0  183.0
# 16   160  1900.0      1038.0  158.0
# 17   110  1750.0       550.0  993.0
# 18    85  1200.0         NaN    NaN
# 19   185  1800.0      2000.0  270.0
# 20   160  1900.0       930.0  150.0
# 21    96  1350.0       747.0    NaN
# 22   148  1600.0      1766.0    NaN
# 23   128  1600.0         NaN  228.0
# 24   120  1800.0       195.0   30.0
# 25   100  1300.0         NaN    NaN
# 26   160  1900.0       880.0    NaN
# 27   160  1900.0       912.0  160.0
# 28   110  1650.0       500.0    NaN
# 29   120  1700.0         NaN    NaN
# 30   190  1200.0         NaN    NaN
# 31   366  1890.0         NaN  208.0
# 32   159  1800.0         NaN    NaN
# 33    99  1800.0         NaN    NaN
# 34   100  1600.0         NaN    NaN
# 35   180  1850.0       300.0    NaN
# 36    80  1600.0       950.0    NaN
# 37   148  1500.0      1600.0  196.0
# 38   180  1900.0         NaN  176.0
# 39   160  1900.0      1038.0    NaN
# 40   120  1600.0         NaN    NaN

# %% [markdown]
# ### Results

# %%
print(f'There are {df_apartments.shape[0]} apartment type values')
print(f'There are {df_houses.shape[0]} house type values')
print(f'There are {df_area_60_100.shape[0]} values where area is between 60 and 100')
print(f'There are {df_room_and_price.shape[0]} values where room is at least 4 and price is up to 2000')
# Out:
# There are 19532 apartment type values
# There are 2212 house type values
# There are 8975 values where area is between 60 and 100
# There are 41 values where room is at least 4 and price is up to 2000
